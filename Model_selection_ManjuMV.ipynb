# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# # Reading Dataset

# %%
data=pd.read_csv(r'C:\Users\manju\Desktop\ICTAK DSA\DATA SETS\csv\titanic_dataset.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Preprocessing dataset

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.shape
# Out:
# (891, 12)

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Checking Missing Values

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
freqgraph=data.select_dtypes(include=['float'])
freqgraph.hist(figsize=(20,15))
plt.show()

# %%
data['Age'].median()
# Out:
# 28.0

# %%
data1=data

# %%
data1.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data1.Cabin.fillna(data1.Cabin.mode()[0],inplace=True)
data1.Embarked.fillna(data1.Embarked.mode()[0],inplace=True)

# %%
data1.Age.fillna(data1.Age.mean(),inplace=True)

# %%
data1.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data1.drop(['Cabin'],axis=1,inplace=True)

# %%
data1['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
data1.drop_duplicates(inplace=True)
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
data1 = data1.drop(['PassengerId','Name','Ticket','Embarked'],axis=1)

# %%
data1.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500

# %% [markdown]
# # Encoding for categorical column

# %%
data1=pd.get_dummies(data1)

# %%
data1.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male
# 0         0       3  22.0      1      0   7.2500           0         1
# 1         1       1  38.0      1      0  71.2833           1         0
# 2         1       3  26.0      0      0   7.9250           1         0
# 3         1       1  35.0      1      0  53.1000           1         0
# 4         0       3  35.0      0      0   8.0500           0         1

# %% [markdown]
# # Checking correlation between independent and dependent variable

# %%
corrmatrix=data1.corr()
plt.subplots(figsize=(10,4))
sns.heatmap(corrmatrix,annot=True,vmin=-0.5,vmax=1,linewidth=0.3,cmap='YlOrRd')
plt.show()

# %%
for i in data:
    sns.boxplot(x=data[i])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27492\3367055244.py in <module>
#       1 for i in data:
# ----> 2     sns.boxplot(x=data[i])
#       3     plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2241 ):
#    2242
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2244                           orient, color, palette, saturation,
# ...

# %%
#outlier columns:Age,SibSp,Parch,Fare

# %% [markdown]
# # Handling Outliers

# %%
#Age

# %%
IQR=stats.iqr(data1.Age,interpolation='midpoint')
IQR
# Out:
# 13.0

# %%
Q1=data1.Age.quantile(0.25)
Q3=data1.Age.quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (2.5, 54.5)

# %%
data1.loc[data1.Age<min_limit]
# Out:
#      Survived  Pclass   Age  SibSp  Parch      Fare  Sex_female  Sex_male
# 7           0       3  2.00      3      1   21.0750           0         1
# 16          0       3  2.00      4      1   29.1250           0         1
# 78          1       2  0.83      0      2   29.0000           0         1
# 119         0       3  2.00      4      2   31.2750           1         0
# 164         0       3  1.00      4      1   39.6875           0         1
# 172         1       3  1.00      1      1   11.1333           1         0
# 183         1       2  1.00      2      1   39.0000           0         1
# 205         0       3  2.00      0      1   10.4625           1         0
# 297         0       1  2.00      1      2  151.5500           1         0
# 305         1       1  0.92      1      2  151.5500           0         1
# 340         1       2  2.00      1      1   26.0000           0         1
# 381         1       3  1.00      0      2   15.7417           1         0
# ...

# %%
data1.loc[data1.Age>max_limit]
# Out:
#      Survived  Pclass   Age  SibSp  Parch      Fare  Sex_female  Sex_male
# 11          1       1  58.0      0      0   26.5500           1         0
# 15          1       2  55.0      0      0   16.0000           1         0
# 33          0       2  66.0      0      0   10.5000           0         1
# 54          0       1  65.0      0      1   61.9792           0         1
# 94          0       3  59.0      0      0    7.2500           0         1
# 96          0       1  71.0      0      0   34.6542           0         1
# 116         0       3  70.5      0      0    7.7500           0         1
# 152         0       3  55.5      0      0    8.0500           0         1
# 170         0       1  61.0      0      0   33.5000           0         1
# 174         0       1  56.0      0      0   30.6958           0         1
# 195         1       1  58.0      0      0  146.5208           1         0
# 232         0       2  59.0      0      0   13.5000           0         1
# ...

# %% [markdown]
# # Removing Outliers Age

# %%
data1.loc[data1['Age']>max_limit,'Age']=np.median(data1.Age)

# %%
data1.loc[data1.Age>max_limit]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Age, SibSp, Parch, Fare, Sex_female, Sex_male]
# Index: []

# %%
data1.loc[data1['Age']<min_limit,'Age']=np.median(data1.Age)

# %%
data1.loc[data1.Age<min_limit]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Age, SibSp, Parch, Fare, Sex_female, Sex_male]
# Index: []

# %% [markdown]
# # SibSp

# %%
IQR=stats.iqr(data1.SibSp,interpolation='midpoint')
IQR
# Out:
# 1.0

# %%
Q1=data1.SibSp.quantile(0.25)
Q3=data1.SibSp.quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (-1.5, 2.5)

# %%
data1.loc[data.SibSp<min_limit]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Age, SibSp, Parch, Fare, Sex_female, Sex_male]
# Index: []

# %%
data1.loc[data.SibSp>max_limit]
# Out:
#      Survived  Pclass        Age  SibSp  Parch      Fare  Sex_female  Sex_male
# 7           0       3  29.699118      3      1   21.0750           0         1
# 16          0       3  29.699118      4      1   29.1250           0         1
# 24          0       3   8.000000      3      1   21.0750           1         0
# 27          0       1  19.000000      3      2  263.0000           0         1
# 50          0       3   7.000000      4      1   39.6875           0         1
# 59          0       3  11.000000      5      2   46.9000           0         1
# 63          0       3   4.000000      3      2   27.9000           0         1
# 68          1       3  17.000000      4      2    7.9250           1         0
# 71          0       3  16.000000      5      2   46.9000           1         0
# 85          1       3  33.000000      3      0   15.8500           1         0
# 88          1       1  23.000000      3      2  263.0000           1         0
# ...

# %% [markdown]
# # removing Sibsp outliers

# %%
data1.loc[data1['SibSp']>max_limit,'SibSp']=np.median(data1.SibSp)
data1.loc[data1['SibSp']<min_limit,'SibSp']=np.median(data1.SibSp)

# %%
data1.loc[data1.SibSp>max_limit]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Age, SibSp, Parch, Fare, Sex_female, Sex_male]
# Index: []

# %%
data1.loc[data1.SibSp<min_limit]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Age, SibSp, Parch, Fare, Sex_female, Sex_male]
# Index: []

# %% [markdown]
# # removing Parch outlier

# %%
IQR=stats.iqr(data1.Parch,interpolation='midpoint')
IQR
# Out:
# 0.0

# %%
Q1=data1.Parch.quantile(0.25)
Q3=data1.Parch.quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (0.0, 0.0)

# %%
data1.loc[data1.Parch<min_limit]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Age, SibSp, Parch, Fare, Sex_female, Sex_male]
# Index: []

# %%
data1.loc[data.Parch>max_limit]
# Out:
#      Survived  Pclass        Age  SibSp  Parch     Fare  Sex_female  Sex_male
# 7           0       3  29.699118      0      1  21.0750           0         1
# 8           1       3  27.000000      0      2  11.1333           1         0
# 10          1       3   4.000000      1      1  16.7000           1         0
# 13          0       3  39.000000      1      5  31.2750           0         1
# 16          0       3  29.699118      0      1  29.1250           0         1
# ..        ...     ...        ...    ...    ...      ...         ...       ...
# 871         1       1  47.000000      1      1  52.5542           1         0
# 879         1       1  29.699118      0      1  83.1583           1         0
# 880         1       2  25.000000      0      1  26.0000           1         0
# 885         0       3  39.000000      0      5  29.1250           1         0
# 888         0       3  29.699118      1      2  23.4500           1         0
#
# [213 rows x 8 columns]

# %%
data1.loc[data1['Parch']>max_limit,'Parch']=np.median(data1.Parch)
data1.loc[data1['Parch']<min_limit,'Parch']=np.median(data1.Parch)

# %%
data1.loc[data1.Parch<min_limit]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Age, SibSp, Parch, Fare, Sex_female, Sex_male]
# Index: []

# %%
data1.loc[data1.Parch>max_limit]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Age, SibSp, Parch, Fare, Sex_female, Sex_male]
# Index: []

# %% [markdown]
# # removing outlier for Fare

# %%
IQR=stats.iqr(data1.Fare,interpolation='midpoint')
IQR
# Out:
# 23.0896

# %%
Q1=data1.Fare.quantile(0.25)
Q3=data1.Fare.quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (-26.724, 65.6344)

# %%
data1.loc[data1.Fare<min_limit]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Age, SibSp, Parch, Fare, Sex_female, Sex_male]
# Index: []

# %%
data1.loc[data1.Fare>max_limit]
# Out:
#      Survived  Pclass        Age  SibSp  Parch      Fare  Sex_female  Sex_male
# 1           1       1  38.000000      1      0   71.2833           1         0
# 27          0       1  19.000000      0      0  263.0000           0         1
# 31          1       1  29.699118      1      0  146.5208           1         0
# 34          0       1  28.000000      1      0   82.1708           0         1
# 52          1       1  49.000000      1      0   76.7292           1         0
# ..        ...     ...        ...    ...    ...       ...         ...       ...
# 846         0       3  29.699118      0      0   69.5500           0         1
# 849         1       1  29.699118      1      0   89.1042           1         0
# 856         1       1  45.000000      1      0  164.8667           1         0
# 863         0       3  29.699118      0      0   69.5500           1         0
# 879         1       1  29.699118      0      0   83.1583           1         0
#
# [116 rows x 8 columns]

# %%
#removing Fare outliers
data1.loc[data1['Fare']>max_limit,'Fare']=np.median(data1.Fare)
data1.loc[data1['Fare']<min_limit,'Fare']=np.median(data1.Fare)

# %%
data1.loc[data1.Fare<min_limit]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Age, SibSp, Parch, Fare, Sex_female, Sex_male]
# Index: []

# %%
data1.loc[data1.Fare>max_limit]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Age, SibSp, Parch, Fare, Sex_female, Sex_male]
# Index: []

# %%
for i in data1:
    sns.boxplot(x=data1[i])
    plt.show()

# %%
y=data1['Survived']
x=data1.drop(['Survived'],axis=1)

# %%
x.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male
# 0       3  22.0      1      0   7.2500           0         1
# 1       1  38.0      1      0  14.4542           1         0
# 2       3  26.0      0      0   7.9250           1         0
# 3       1  35.0      1      0  53.1000           1         0
# 4       3  35.0      0      0   8.0500           0         1

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %% [markdown]
# # Scaling and normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
data1.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male
# 0         0       3  22.0      1      0   7.2500           0         1
# 1         1       1  38.0      1      0  14.4542           1         0
# 2         1       3  26.0      0      0   7.9250           1         0
# 3         1       1  35.0      1      0  53.1000           1         0
# 4         0       3  35.0      0      0   8.0500           0         1

# %%
df=pd.DataFrame(data1)
df
# Out:
#      Survived  Pclass        Age  SibSp  Parch     Fare  Sex_female  Sex_male
# 0           0       3  22.000000      1      0   7.2500           0         1
# 1           1       1  38.000000      1      0  14.4542           1         0
# 2           1       3  26.000000      0      0   7.9250           1         0
# 3           1       1  35.000000      1      0  53.1000           1         0
# 4           0       3  35.000000      0      0   8.0500           0         1
# ..        ...     ...        ...    ...    ...      ...         ...       ...
# 886         0       2  27.000000      0      0  13.0000           0         1
# 887         1       1  19.000000      0      0  30.0000           1         0
# 888         0       3  29.699118      1      0  23.4500           1         0
# 889         1       1  26.000000      0      0  30.0000           0         1
# 890         0       3  32.000000      0      0   7.7500           0         1
#
# [891 rows x 8 columns]

# %%
#Creating Instance
scaler=MinMaxScaler()
#Fitting the model

df_scaled=pd.DataFrame(scaler.fit_transform(df),columns=df.columns)
df_scaled
# Out:
#      Survived  Pclass       Age  SibSp  Parch      Fare  Sex_female  Sex_male
# 0         0.0     1.0  0.372549    0.5    0.0  0.111538         0.0       1.0
# 1         1.0     0.0  0.686275    0.5    0.0  0.222372         1.0       0.0
# 2         1.0     1.0  0.450980    0.0    0.0  0.121923         1.0       0.0
# 3         1.0     0.0  0.627451    0.5    0.0  0.816923         1.0       0.0
# 4         0.0     1.0  0.627451    0.0    0.0  0.123846         0.0       1.0
# ..        ...     ...       ...    ...    ...       ...         ...       ...
# 886       0.0     0.5  0.470588    0.0    0.0  0.200000         0.0       1.0
# 887       1.0     0.0  0.313725    0.0    0.0  0.461538         1.0       0.0
# 888       0.0     1.0  0.523512    0.5    0.0  0.360769         1.0       0.0
# 889       1.0     0.0  0.450980    0.0    0.0  0.461538         0.0       1.0
# 890       0.0     1.0  0.568627    0.0    0.0  0.119231         0.0       1.0
#
# [891 rows x 8 columns]

# %%
# normalize

# %%
from sklearn import preprocessing

# %%
df=preprocessing.normalize(data1)
norm_df=pd.DataFrame(df,columns=data1.columns)
norm_df
# Out:
#      Survived    Pclass       Age     SibSp  Parch      Fare  Sex_female  \
# 0    0.000000  0.128205  0.940169  0.042735    0.0  0.309828    0.000000
# 1    0.024567  0.024567  0.933539  0.024567    0.0  0.355094    0.024567
# 2    0.036520  0.109559  0.949509  0.000000    0.0  0.289418    0.036520
# 3    0.015716  0.015716  0.550066  0.015716    0.0  0.834529    0.015716
# 4    0.000000  0.083211  0.970799  0.000000    0.0  0.223284    0.000000
# ..        ...       ...       ...       ...    ...       ...         ...
# 886  0.000000  0.066556  0.898504  0.000000    0.0  0.432613    0.000000
# 887  0.028127  0.028127  0.534417  0.000000    0.0  0.843816    0.028127
# 888  0.000000  0.078976  0.781843  0.026325    0.0  0.617332    0.026325
# 889  0.025166  0.025166  0.654308  0.000000    0.0  0.754971    0.000000
# 890  0.000000  0.090699  0.967451  0.000000    0.0  0.234305    0.000000
#
#      Sex_male
# 0    0.042735
# 1    0.000000
# 2    0.000000
# 3    0.000000
# ...

# %%
data1.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Sex_female    0
# Sex_male      0
# dtype: int64

# %% [markdown]
# # Hold out Technique

# %%
#Split the data for train and test

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# # KNN and SVM Models

# %%
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

# %%
metric_k=[]
neighbors=np.arange(3,15)

for k in neighbors:
    classifier=KNeighborsClassifier(n_neighbors=k,metric='minkowski',p=2)
    model=classifier.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    acc=accuracy_score(y_test,y_pred)
    metric_k.append(acc)
# Out:
# C:\Users\manju\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
metric_k
# Out:
# [0.6815642458100558,
#  0.6927374301675978,
#  0.6871508379888268,
#  0.6927374301675978,
#  0.6983240223463687,
#  0.6759776536312849,
#  0.6815642458100558,
#  0.6703910614525139,
#  0.6759776536312849,
#  0.664804469273743,
#  0.6703910614525139,
#  0.6480446927374302]

# %%
#Plotting the values 

plt.plot(neighbors,metric_k,'o-')
plt.xlabel('k value')
plt.ylabel('accuracy')
plt.grid()

# %%
#Accuracy is more in 7

#Choosing k as 7


for k in neighbors:
    classifier = KNeighborsClassifier(n_neighbors=7,metric='minkowski',p=2)
    model=classifier.fit(x_train,y_train)
    y_pred_knn=model.predict(x_test)
    acc=accuracy_score(y_test,y_pred_knn)
# Out:
# C:\Users\manju\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
print('Accuracy=',accuracy_score(y_test,y_pred_knn))
print('Precision=',precision_score(y_test,y_pred_knn))
print('Recall=',recall_score(y_test,y_pred_knn))
print('F1 score=',f1_score(y_test,y_pred_knn))
# Out:
# Accuracy= 0.6983240223463687
# Precision= 0.6666666666666666
# Recall= 0.5405405405405406
# F1 score= 0.5970149253731343

# %%
#anotherr way to get accuracy

# %%
KNN_model=classifier.fit(x_train,y_train)

# %%
score_KNN=KNN_model.score(x_test,y_test)
score_KNN
# Out:
# C:\Users\manju\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 0.6983240223463687

# %% [markdown]
# # K Fold Cross Valuation

# %%
from sklearn.model_selection import KFold
kfold_validator = KFold(10)

# %%
for train_index, test_index in kfold_validator.split(x,y):
    print('Training Index: ',train_index)
    print('Validation Index: ',test_index)
# Out:
# Training Index:  [ 90  91  92  93  94  95  96  97  98  99 100 101 102 103 104 105 106 107
#  108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125
#  126 127 128 129 130 131 132 133 134 135 136 137 138 139 140 141 142 143
#  144 145 146 147 148 149 150 151 152 153 154 155 156 157 158 159 160 161
#  162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179
#  180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197
#  198 199 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214 215
#  216 217 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232 233
#  234 235 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250 251
#  252 253 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268 269
#  270 271 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286 287
#  288 289 290 291 292 293 294 295 296 297 298 299 300 301 302 303 304 305
#  306 307 308 309 310 311 312 313 314 315 316 317 318 319 320 321 322 323
# ...

# %%
from sklearn.model_selection import cross_val_score
cv_score = cross_val_score(KNN_model,x,y,cv= kfold_validator)
# Out:
# C:\Users\manju\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
cv_score
# Out:
# array([0.71111111, 0.71910112, 0.69662921, 0.70786517, 0.74157303,
#        0.70786517, 0.71910112, 0.76404494, 0.82022472, 0.79775281])

# %%
#taking average score of cv score

# %%
np.mean(cv_score)
# Out:
# 0.7385268414481898

# %% [markdown]
# # Stratified k fold cross validation

# %%
from sklearn.model_selection import StratifiedKFold

# %%
skfold_validator=StratifiedKFold(n_splits=10)

# %%
for train_index,test_index in skfold_validator.split(x,y):
    print('Training index :',train_index)
    print('Testing index :',test_index)
# Out:
# Training index : [ 82  84  85  88  94  95  96  97  98  99 100 101 102 103 104 105 106 107
#  108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125
#  126 127 128 129 130 131 132 133 134 135 136 137 138 139 140 141 142 143
#  144 145 146 147 148 149 150 151 152 153 154 155 156 157 158 159 160 161
#  162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179
#  180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197
#  198 199 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214 215
#  216 217 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232 233
#  234 235 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250 251
#  252 253 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268 269
#  270 271 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286 287
#  288 289 290 291 292 293 294 295 296 297 298 299 300 301 302 303 304 305
#  306 307 308 309 310 311 312 313 314 315 316 317 318 319 320 321 322 323
# ...

# %%
skcv_score=cross_val_score(KNN_model,x,y,cv=skfold_validator)

skcv_score
# Out:
# C:\Users\manju\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
#Taking average of skcv score

np.mean(skcv_score)
# Out:
# 0.7430337078651685

# %% [markdown]
# # SVM

# %%
#Adding kernels

from sklearn.svm import SVC
svmclf=SVC(kernel='linear')

#Fitting the data

svmclf.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
#Predicting the models

y_pred_svm=svmclf.predict(x_test)

# %%
#Checking the accuracy

from sklearn.metrics import accuracy_score,confusion_matrix

# %%
print('accuracy=',accuracy_score(y_test,y_pred_svm))
# Out:
# accuracy= 0.7821229050279329

# %%
print('confusion_matrix=',confusion_matrix(y_test,y_pred_svm))
# Out:
# confusion_matrix= [[88 17]
#  [22 52]]

# %% [markdown]
# # SBF

# %%
#Adding kernels

from sklearn.svm import SVC
svmclf=SVC(kernel='rbf')
SVM_model=svmclf.fit(x_train,y_train)
SVM_model
# Out:
# SVC()

# %%
y_pred_svm=svmclf.predict(x_test)
print('Accuracy = ',accuracy_score(y_test,y_pred_svm))
# Out:
# Accuracy =  0.6145251396648045

# %%
#Another way to find accuracy

SVM_score=SVM_model.score(x_test,y_test)

# %%
SVM_score
# Out:
# 0.6145251396648045

# %% [markdown]
# # polynomial

# %%
#Adding kernels

from sklearn.svm import SVC
svmclf=SVC(kernel='poly')

#Fitting the data

svmclf.fit(x_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
#predicting and printing
y_pred_svm=svmclf.predict(x_test)
print('Accuracy = ',accuracy_score(y_test,y_pred_svm))
# Out:
# Accuracy =  0.6424581005586593

# %% [markdown]
# # K fold cross validation

# %%
#Importing K fold from sklearn library
from sklearn.model_selection import KFold

# %%
#Creating Instance and specify number of folds to do the iterations

kfold_validator=KFold(10)

# %%
#Giving entire data for validation(400 rows and 5 columns) and check what columns are taking for validation and training
for train_index,test_index in kfold_validator.split(x,y):
    print('Training index :',train_index)
    print('Testing index :',test_index)
# Out:
# Training index : [ 90  91  92  93  94  95  96  97  98  99 100 101 102 103 104 105 106 107
#  108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125
#  126 127 128 129 130 131 132 133 134 135 136 137 138 139 140 141 142 143
#  144 145 146 147 148 149 150 151 152 153 154 155 156 157 158 159 160 161
#  162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179
#  180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197
#  198 199 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214 215
#  216 217 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232 233
#  234 235 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250 251
#  252 253 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268 269
#  270 271 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286 287
#  288 289 290 291 292 293 294 295 296 297 298 299 300 301 302 303 304 305
#  306 307 308 309 310 311 312 313 314 315 316 317 318 319 320 321 322 323
# ...

# %%
#Importing to get the score

from sklearn.model_selection import cross_val_score

# %%
cv_score=cross_val_score(SVM_model,x,y,cv=kfold_validator)

# %%
cv_score
# Out:
# array([0.56666667, 0.74157303, 0.61797753, 0.53932584, 0.60674157,
#        0.6741573 , 0.61797753, 0.69662921, 0.70786517, 0.61797753])

# %%
#Taking average of cv score

np.mean(cv_score)
# Out:
# 0.638689138576779

# %% [markdown]
# # Stratified k-fold Cross Validation

# %%
from sklearn.model_selection import StratifiedKFold

# %%
skfold_validator=StratifiedKFold(n_splits=10)

# %%
#Giving entire data for validation and check what columns are taking for validation and training

for train_index,test_index in skfold_validator.split(x,y):
    print('Training index :',train_index)
    print('Testing index :',test_index)
# Out:
# Training index : [ 82  84  85  88  94  95  96  97  98  99 100 101 102 103 104 105 106 107
#  108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125
#  126 127 128 129 130 131 132 133 134 135 136 137 138 139 140 141 142 143
#  144 145 146 147 148 149 150 151 152 153 154 155 156 157 158 159 160 161
#  162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179
#  180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197
#  198 199 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214 215
#  216 217 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232 233
#  234 235 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250 251
#  252 253 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268 269
#  270 271 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286 287
#  288 289 290 291 292 293 294 295 296 297 298 299 300 301 302 303 304 305
#  306 307 308 309 310 311 312 313 314 315 316 317 318 319 320 321 322 323
# ...

# %%
skcv_score=cross_val_score(SVM_model,x,y,cv=skfold_validator)

skcv_score
# Out:
# array([0.6       , 0.61797753, 0.60674157, 0.65168539, 0.65168539,
#        0.65168539, 0.65168539, 0.68539326, 0.68539326, 0.59550562])

# %%
#Taking average of skcv score
np.mean(skcv_score)
# Out:
# 0.6397752808988765
